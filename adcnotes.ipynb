# %% [markdown]
# On the STM32F407 microcontroller, the ADC1 (Analog-to-Digital Converter 1) is connected to the Advanced High-Performance Bus (AHB2) domain.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tconv= ST+ Cv/42 10^3 = st+15/ 42 10^6 =(18/42)/10^6
